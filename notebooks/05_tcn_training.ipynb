# %% [markdown]
# # 05 - TCN Training
#
# Notebook nay train `TCN pathway` bang pipeline `pipelines/train_tcn.py`.

# %%
REPO_URL = 'https://github.com/ntdev204/adaptive-context-aware.git'
REPO_DIR = '/content/adaptive-context-aware'
# !rm -rf {REPO_DIR}
# !git clone {REPO_URL} {REPO_DIR}
# %cd {REPO_DIR}
# !python -m pip install --upgrade pip
# !python -m pip install -e .[dev]

# %%
# !python pipelines/train_tcn.py --samples 512 --sequence-length 8 --epochs 30 --checkpoint-path models/checkpoints/tcn_pathway.pt

# %%
# !ls -lah models/checkpoints
