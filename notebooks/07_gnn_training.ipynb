# %% [markdown]
# # 07 - GNN Training

# %%
REPO_URL = 'https://github.com/ntdev204/adaptive-context-aware.git'
REPO_DIR = '/content/adaptive-context-aware'
# !rm -rf {REPO_DIR}
# !git clone {REPO_URL} {REPO_DIR}
# %cd {REPO_DIR}
# !python -m pip install -e .[dev]

# %%
# !python pipelines/train_gnn.py --plan-only
