# %% [markdown]
# # 08 - Reasoning Heads Training
#
# Notebook nay gom cac module reasoning cap cao hien co pipeline rieng:
# - `gated_fusion`
# - `intent_predictor`
# - `anomaly_detector`
# - `train_reasoning.py` neu muon chay end-to-end.

# %%
REPO_URL = "https://github.com/ntdev204/adaptive-context-aware.git"
REPO_DIR = "/content/adaptive-context-aware"
# !rm -rf {REPO_DIR}
# !git clone {REPO_URL} {REPO_DIR}
# %cd {REPO_DIR}
# !python -m pip install --upgrade pip
# !python -m pip install -e .[dev]

# %%
# !python pipelines/train_fusion.py --samples 512 --epochs 30 --checkpoint-path models/checkpoints/gated_fusion.pt
# !python pipelines/train_intent_predictor.py --samples 512 --epochs 30 --checkpoint-path models/checkpoints/intent_predictor.pt
# !python pipelines/train_anomaly_detector.py --samples 512 --epochs 30 --checkpoint-path models/checkpoints/anomaly_detector.pt

# %%
# !python -m pipelines.train_reasoning --samples 1024 --epochs 50 --checkpoint-path models/checkpoints/reasoning_brain.pt

# %%
# !ls -lah models/checkpoints
